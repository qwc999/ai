# %% [markdown]
# # Лабораторная работа №5 (Проведение исследований с градиентным бустингом)

# %% [markdown]
# ### Создание бейзлайна и оценка качества

# %% [markdown]
# Импорт необходимых библиотек.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor

# %% [markdown]
# Подготовка данных.

# %%
path = 'drive/MyDrive/ai_data/'
heart = pd.read_csv(path + 'heart.csv')
heart.shape, heart.columns
# Out:
# ((918, 12),
#  Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#         'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#         'HeartDisease'],
#        dtype='object'))

# %% [markdown]
# Посмотрим состав таблицы и наличие пропусков, а также баланс HeartDisease.

# %%
display(heart.head())
display(heart.info())
display(heart.describe())
print("Missing per column:\n", heart.isna().sum())
print(heart['HeartDisease'].value_counts(normalize=True))
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB
# None
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000
# Missing per column:
#  Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64
# HeartDisease
# 1    0.553377
# 0    0.446623
# Name: proportion, dtype: float64

# %% [markdown]
# Выполним те же действия для второго датасета.

# %%
melbourne = pd.read_csv(path + 'melb_data.csv')
melbourne.shape, melbourne.columns
# Out:
# ((13580, 21),
#  Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#         'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#         'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#         'Longtitude', 'Regionname', 'Propertycount'],
#        dtype='object'))

# %%
display(melbourne.head())
display(melbourne.info())
display(melbourne.describe())
print(melbourne.isna().sum())
print(melbourne['Price'].describe())
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 2.2+ MB
# None
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# std        0.691712      0.962634    3990.669241    541.014538    37.273762
# min        0.000000      0.000000       0.000000      0.000000  1196.000000
# 25%        1.000000      1.000000     177.000000     93.000000  1940.000000
# 50%        1.000000      2.000000     440.000000    126.000000  1970.000000
# 75%        2.000000      2.000000     651.000000    174.000000  1999.000000
# max        8.000000     10.000000  433014.000000  44515.000000  2018.000000
#
#           Lattitude    Longtitude  Propertycount
# count  13580.000000  13580.000000   13580.000000
# mean     -37.809203    144.995216    7454.417378
# std        0.079260      0.103916    4378.581772
# min      -38.182550    144.431810     249.000000
# 25%      -37.856822    144.929600    4380.000000
# 50%      -37.802355    145.000100    6555.000000
# 75%      -37.756400    145.058305   10331.000000
# max      -37.408530    145.526350   21650.000000
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64
# count    1.358000e+04
# mean     1.075684e+06
# std      6.393107e+05
# min      8.500000e+04
# 25%      6.500000e+05
# 50%      9.030000e+05
# 75%      1.330000e+06
# max      9.000000e+06
# Name: Price, dtype: float64

# %% [markdown]
# Удалим столбцы с большим количеством пропусков, заполним столбцы с маленьким количеством пропусков медианой и модой

# %%
columns_to_drop = ['BuildingArea', 'YearBuilt']
melbourne_clean = melbourne.drop(columns=columns_to_drop)

car_median = melbourne_clean['Car'].median()
melbourne_clean['Car'] = melbourne_clean['Car'].fillna(car_median)

council_mode = melbourne_clean['CouncilArea'].mode()[0]
melbourne_clean['CouncilArea'] = melbourne_clean['CouncilArea'].fillna(council_mode)

print(melbourne_clean.isna().sum())
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [markdown]
# Разделим данные на тренировочную и тестовую выборки:

# %%
X_heart = heart.drop('HeartDisease', axis=1)
y_heart = heart['HeartDisease']
X_heart_train, X_heart_test, y_heart_train, y_heart_test = train_test_split(
    X_heart, y_heart, test_size=0.2, random_state=42, stratify=y_heart
)


X_melbourne = melbourne_clean.drop('Price', axis=1)
y_melbourne = melbourne_clean['Price']
X_melbourne_train, X_melbourne_test, y_melbourne_train, y_melbourne_test = train_test_split(
    X_melbourne, y_melbourne, test_size=0.2, random_state=42
)

# %% [markdown]
# Проведем обработку категориальных переменных:

# %%
X_heart_train_processed = X_heart_train.copy()
X_heart_test_processed = X_heart_test.copy()
X_melbourne_train_processed = X_melbourne_train.copy()
X_melbourne_test_processed = X_melbourne_test.copy()

# %% [markdown]
# Обработка категориальных переменных для Heart dataset:

# %%
categorical_heart = ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
for col in categorical_heart:
    print(f"{col}: {X_heart_train[col].unique()}")

label_encoders_heart = {}
for col in categorical_heart:
    le = LabelEncoder()
    X_heart_train_processed[col] = le.fit_transform(X_heart_train[col])
    X_heart_test_processed[col] = le.transform(X_heart_test[col])
    label_encoders_heart[col] = le

print("\nРезультат:")
print(X_heart_train_processed[categorical_heart].head())
print(f"{X_heart_train_processed[categorical_heart].dtypes}")
# Out:
# Sex: ['M' 'F']
# ChestPainType: ['ATA' 'ASY' 'NAP' 'TA']
# RestingECG: ['ST' 'Normal' 'LVH']
# ExerciseAngina: ['Y' 'N']
# ST_Slope: ['Flat' 'Up' 'Down']
#
# Результат:
#      Sex  ChestPainType  RestingECG  ExerciseAngina  ST_Slope
# 485    1              1           2               1         1
# 486    1              1           2               0         2
# 117    0              0           2               1         1
# 361    1              0           1               1         1
# 296    1              0           1               1         1
# Sex               int64
# ChestPainType     int64
# RestingECG        int64
# ExerciseAngina    int64
# ST_Slope          int64
# dtype: object

# %% [markdown]
# Обработка категориальных переменных для Melbourne dataset. Применяем One-Hot Encoding для сложных категориальных признаков. Удаляем нечисловые столбцы, которые не будем использовать.

# %%
categorical_melbourne = ['Type', 'Method', 'CouncilArea', 'Regionname']
for col in categorical_melbourne:
    print(f"{col}: {X_melbourne_train[col].nunique()}")

simple_categorical = ['Type', 'Method']
complex_categorical = ['CouncilArea', 'Regionname']

label_encoders_melbourne = {}
for col in simple_categorical:
    le = LabelEncoder()
    X_melbourne_train_processed[col] = le.fit_transform(X_melbourne_train[col])
    X_melbourne_test_processed[col] = le.transform(X_melbourne_test[col])
    label_encoders_melbourne[col] = le


council_dummies_train = pd.get_dummies(X_melbourne_train['CouncilArea'], prefix='Council', dtype=int)
region_dummies_train = pd.get_dummies(X_melbourne_train['Regionname'], prefix='Region', dtype=int)
council_dummies_test = pd.get_dummies(X_melbourne_test['CouncilArea'], prefix='Council', dtype=int)
region_dummies_test = pd.get_dummies(X_melbourne_test['Regionname'], prefix='Region', dtype=int)

council_dummies_test = council_dummies_test.reindex(columns=council_dummies_train.columns, fill_value=0)
region_dummies_test = region_dummies_test.reindex(columns=region_dummies_train.columns, fill_value=0)

X_melbourne_train_processed = X_melbourne_train_processed.drop(['CouncilArea', 'Regionname'], axis=1)
X_melbourne_test_processed = X_melbourne_test_processed.drop(['CouncilArea', 'Regionname'], axis=1)

X_melbourne_train_processed = pd.concat([X_melbourne_train_processed, council_dummies_train, region_dummies_train], axis=1)
X_melbourne_test_processed = pd.concat([X_melbourne_test_processed, council_dummies_test, region_dummies_test], axis=1)

columns_to_drop_melbourne = ['Suburb', 'Address', 'SellerG', 'Date']
X_melbourne_train_processed = X_melbourne_train_processed.drop(columns=columns_to_drop_melbourne, errors='ignore')
X_melbourne_test_processed = X_melbourne_test_processed.drop(columns=columns_to_drop_melbourne, errors='ignore')

print(f"Итого: {X_melbourne_train_processed.shape[1]} признаков")
# Out:
# Type: 3
# Method: 5
# CouncilArea: 33
# Regionname: 8
# Итого: 53 признаков

# %% [markdown]
# Итоговые размер данных и типы данных:

# %%
print(f"Heart train: {X_heart_train_processed.shape}")
print(f"Heart test: {X_heart_test_processed.shape}")
print(f"Melbourne train: {X_melbourne_train_processed.shape}")
print(f"Melbourne test: {X_melbourne_test_processed.shape}")

print(f"Heart: {X_heart_train_processed.dtypes.unique()}")
print(f"Melbourne: {X_melbourne_train_processed.dtypes.unique()}")
# Out:
# Heart train: (734, 11)
# Heart test: (184, 11)
# Melbourne train: (10864, 53)
# Melbourne test: (2716, 53)
# Heart: [dtype('int64') dtype('float64')]
# Melbourne: [dtype('int64') dtype('float64')]

# %% [markdown]
# Проведем масштабирование признаков:

# %%
scaler_heart = StandardScaler()
X_heart_train_scaled = scaler_heart.fit_transform(X_heart_train_processed)
X_heart_test_scaled = scaler_heart.transform(X_heart_test_processed)

scaler_melbourne = StandardScaler()
X_melbourne_train_scaled = scaler_melbourne.fit_transform(X_melbourne_train_processed)
X_melbourne_test_scaled = scaler_melbourne.transform(X_melbourne_test_processed)

# %% [markdown]
# #### Обучение моделей

# %%
gb_classifier = GradientBoostingClassifier(random_state=42)
gb_classifier.fit(X_heart_train_scaled, y_heart_train)

y_heart_pred = gb_classifier.predict(X_heart_test_scaled)

gb_regressor = GradientBoostingRegressor(random_state=42)
gb_regressor.fit(X_melbourne_train_scaled, y_melbourne_train)

y_melbourne_pred = gb_regressor.predict(X_melbourne_test_scaled)

# %% [markdown]
# #### Оценка качества моделей

# %%
accuracy = accuracy_score(y_heart_test, y_heart_pred)
recall = recall_score(y_heart_test, y_heart_pred)

print("Классификация:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Recall: {recall:.4f}")

r2 = r2_score(y_melbourne_test, y_melbourne_pred)
mae = mean_absolute_error(y_melbourne_test, y_melbourne_pred)

print("\nРегрессия:")
print(f"R2: {r2:.4f}")
print(f"MAE: {mae:,.2f}")
# Out:
# Классификация:
# Accuracy: 0.8859
# Recall: 0.8922
#
# Регрессия:
# R2: 0.7785
# MAE: 191,440.08

# %% [markdown]
# ### Улучшение бейзлайна

# %% [markdown]
# Гипотезы:
# 1. Оптимальная глубина деревьев позволит модели лучше выявлять сложные зависимости, что позволит улучшить метрики.
# 2. Настройка learning rate и subsample позволит улучшить метрики.
# 3. Кросс-валидация позволит избежать подгонки под тестовую выборку и найти более стабильные параметры.

# %% [markdown]
# Гипотеза 1:

# %%
param_grid_depth = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7, 9]
}

grid_class_depth = GridSearchCV(
    GradientBoostingClassifier(random_state=42),
    param_grid_depth,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)
grid_class_depth.fit(X_heart_train_scaled, y_heart_train)

print("Лучшие параметры для классификации:")
print(grid_class_depth.best_params_)
print(f"Лучшая accuracy на кросс-валидации: {grid_class_depth.best_score_:.4f}")

grid_reg_depth = GridSearchCV(
    GradientBoostingRegressor(random_state=42),
    param_grid_depth,
    cv=5,
    scoring='r2',
    n_jobs=-1
)
grid_reg_depth.fit(X_melbourne_train_scaled, y_melbourne_train)

print("\nЛучшие параметры для регрессии:")
print(grid_reg_depth.best_params_)
print(f"Лучший R2 на кросс-валидации: {grid_reg_depth.best_score_:.4f}")
# Out:
# Лучшие параметры для классификации:
# {'max_depth': 3, 'n_estimators': 150}
# Лучшая accuracy на кросс-валидации: 0.8487
#
# Лучшие параметры для регрессии:
# {'max_depth': 5, 'n_estimators': 150}
# Лучший R2 на кросс-валидации: 0.7917

# %% [markdown]
# Гипотеза 2:

# %%
param_grid_lr = {
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0]
}

grid_class_lr = GridSearchCV(
    GradientBoostingClassifier(random_state=42),
    param_grid_lr,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)
grid_class_lr.fit(X_heart_train_scaled, y_heart_train)

print("Лучшие параметры для классификации:")
print(grid_class_lr.best_params_)
print(f"Лучшая accuracy на кросс-валидации: {grid_class_lr.best_score_:.4f}")

grid_reg_lr = GridSearchCV(
    GradientBoostingRegressor(random_state=42),
    param_grid_lr,
    cv=5,
    scoring='r2',
    n_jobs=-1
)
grid_reg_lr.fit(X_melbourne_train_scaled, y_melbourne_train)

print("\nЛучшие параметры для регрессии:")
print(grid_reg_lr.best_params_)
print(f"Лучший R2 на кросс-валидации: {grid_reg_lr.best_score_:.4f}")
# Out:
# Лучшие параметры для классификации:
# {'learning_rate': 0.05, 'subsample': 0.8}
# Лучшая accuracy на кросс-валидации: 0.8651
#
# Лучшие параметры для регрессии:
# {'learning_rate': 0.2, 'subsample': 0.8}
# Лучший R2 на кросс-валидации: 0.7750

# %% [markdown]
# Гипотеза 3:

# %%
param_grid_full = {
    'n_estimators': [100, 150],
    'max_depth': [3, 5],
    'learning_rate': [0.05, 0.1],
    'subsample': [0.8, 1.0]
}

grid_class_full = GridSearchCV(
    GradientBoostingClassifier(random_state=42),
    param_grid_full,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)
grid_class_full.fit(X_heart_train_scaled, y_heart_train)

print("Лучшие параметры для классификации:")
print(grid_class_full.best_params_)
print(f"Лучшая accuracy на кросс-валидации: {grid_class_full.best_score_:.4f}")

grid_reg_full = GridSearchCV(
    GradientBoostingRegressor(random_state=42),
    param_grid_full,
    cv=5,
    scoring='r2',
    n_jobs=-1
)
grid_reg_full.fit(X_melbourne_train_scaled, y_melbourne_train)

print("\nЛучшие параметры для регрессии:")
print(grid_reg_full.best_params_)
print(f"Лучший R2 на кросс-валидации: {grid_reg_full.best_score_:.4f}")
# Out:
# Лучшие параметры для классификации:
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
# Лучшая accuracy на кросс-валидации: 0.8651
#
# Лучшие параметры для регрессии:
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 150, 'subsample': 0.8}
# Лучший R2 на кросс-валидации: 0.7934

# %% [markdown]
# По отдельности изменение параметров может давать результат хуже обычного бейзлайна. Сформируем улучшенный бейзлайн с имплементацией параметров из гипотезы 3. Если получим улучшение метрик, будем считать, что гипотезы подтвердились.

# %%
best_gb_classifier = GradientBoostingClassifier(
    learning_rate=0.05,
    max_depth=3,
    n_estimators=100,
    subsample=0.8,
    random_state=42
)
best_gb_classifier.fit(X_heart_train_scaled, y_heart_train)

y_heart_pred_improved = best_gb_classifier.predict(X_heart_test_scaled)

best_gb_regressor = GradientBoostingRegressor(
    learning_rate=0.1,
    max_depth=5,
    n_estimators=150,
    subsample=0.8,
    random_state=42
)
best_gb_regressor.fit(X_melbourne_train_scaled, y_melbourne_train)

y_melbourne_pred_improved = best_gb_regressor.predict(X_melbourne_test_scaled)

accuracy_improved = accuracy_score(y_heart_test, y_heart_pred_improved)
recall_improved = recall_score(y_heart_test, y_heart_pred_improved)

r2_improved = r2_score(y_melbourne_test, y_melbourne_pred_improved)
mae_improved = mean_absolute_error(y_melbourne_test, y_melbourne_pred_improved)

print("\nКлассификация:")
print(f"Базовый бейзлайн - Accuracy: {accuracy:.4f}, Recall: {recall:.4f}")
print(f"Улучшенный - Accuracy: {accuracy_improved:.4f}, Recall: {recall_improved:.4f}")

print("\nРегрессия:")
print(f"Базовый бейзлайн - R2: {r2:.4f}, MAE: {mae:,.2f}")
print(f"Улучшенный - R2: {r2_improved:.4f}, MAE: {mae_improved:,.2f}")
# Out:
# Классификация:
# Базовый бейзлайн - Accuracy: 0.8859, Recall: 0.8922
# Улучшенный - Accuracy: 0.9130, Recall: 0.9412
#
# Регрессия:
# Базовый бейзлайн - R2: 0.7785, MAE: 191,440.08
# Улучшенный - R2: 0.8302, MAE: 163,950.56

# %% [markdown]
# Получили значительное увеличение качества. Гипотезы подтвердились.
#
# Выводы по улучшению бейзлайна:
# - Все три гипотезы подтвердились и были успешно имплементированы в улучшенный бейзлайн.
# - Градиентный бустинг чувствителен к настройке гиперпараметров, и их правильный подбор через кросс-валидацию существенно повышает качество моделей для обеих задач.

# %% [markdown]
# ### Имплементация алгоритма машинного обучения

# %% [markdown]
# Релизация для регресии и классификации в виде классов:

# %%
class CustomGradientBoostingClassifier:
    def __init__(self, n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42):
        self.n_estimators = n_estimators
        self.learning_rate = learning_rate
        self.max_depth = max_depth
        self.random_state = random_state
        self.trees = []
        self.initial_prediction = None

    def _sigmoid(self, x):
        return 1 / (1 + np.exp(-np.clip(x, -500, 500)))

    def fit(self, X, y):
        from sklearn.tree import DecisionTreeRegressor

        X = np.array(X)
        y = np.array(y)

        self.initial_prediction = np.log(np.mean(y) / (1 - np.mean(y) + 1e-10))
        predictions = np.full(len(y), self.initial_prediction)

        for _ in range(self.n_estimators):
            probabilities = self._sigmoid(predictions)
            residuals = y - probabilities

            tree = DecisionTreeRegressor(max_depth=self.max_depth, random_state=self.random_state)
            tree.fit(X, residuals)

            update = tree.predict(X)
            predictions += self.learning_rate * update

            self.trees.append(tree)

        return self

    def predict_proba(self, X):
        X = np.array(X)
        predictions = np.full(len(X), self.initial_prediction)

        for tree in self.trees:
            predictions += self.learning_rate * tree.predict(X)

        probabilities = self._sigmoid(predictions)
        return np.column_stack([1 - probabilities, probabilities])

    def predict(self, X):
        probabilities = self.predict_proba(X)[:, 1]
        return (probabilities >= 0.5).astype(int)


class CustomGradientBoostingRegressor:
    def __init__(self, n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42):
        self.n_estimators = n_estimators
        self.learning_rate = learning_rate
        self.max_depth = max_depth
        self.random_state = random_state
        self.trees = []
        self.initial_prediction = None

    def fit(self, X, y):
        from sklearn.tree import DecisionTreeRegressor

        X = np.array(X)
        y = np.array(y)

        self.initial_prediction = np.mean(y)
        predictions = np.full(len(y), self.initial_prediction)

        for _ in range(self.n_estimators):
            residuals = y - predictions

            tree = DecisionTreeRegressor(max_depth=self.max_depth, random_state=self.random_state)
            tree.fit(X, residuals)

            update = tree.predict(X)
            predictions += self.learning_rate * update

            self.trees.append(tree)

        return self

    def predict(self, X):
        X = np.array(X)
        predictions = np.full(len(X), self.initial_prediction)

        for tree in self.trees:
            predictions += self.learning_rate * tree.predict(X)

        return predictions


custom_gb_classifier = CustomGradientBoostingClassifier(random_state=42)
custom_gb_classifier.fit(X_heart_train_scaled, y_heart_train)
y_heart_pred_custom = custom_gb_classifier.predict(X_heart_test_scaled)

custom_gb_regressor = CustomGradientBoostingRegressor(random_state=42)
custom_gb_regressor.fit(X_melbourne_train_scaled, y_melbourne_train)
y_melbourne_pred_custom = custom_gb_regressor.predict(X_melbourne_test_scaled)

# %% [markdown]
# Посмотрим на результаты и сравним их с базовым бейзайном:

# %%
accuracy_custom = accuracy_score(y_heart_test, y_heart_pred_custom)
recall_custom = recall_score(y_heart_test, y_heart_pred_custom)

r2_custom = r2_score(y_melbourne_test, y_melbourne_pred_custom)
mae_custom = mean_absolute_error(y_melbourne_test, y_melbourne_pred_custom)

print("Самостоятельная имплементация:")
print(f"Классификация - Accuracy: {accuracy_custom:.4f}, Recall: {recall_custom:.4f}")
print(f"Регрессия - R2: {r2_custom:.4f}, MAE: {mae_custom:,.2f}")

print("\nСравнение с базовым бейзлайном:")
print(f"Классификация - Sklearn Accuracy: {accuracy:.4f}, Custom Accuracy: {accuracy_custom:.4f}")
print(f"Регрессия - Sklearn R2: {r2:.4f}, Custom R2: {r2_custom:.4f}")
# Out:
# Самостоятельная имплементация:
# Классификация - Accuracy: 0.8750, Recall: 0.9216
# Регрессия - R2: 0.7783, MAE: 191,528.43
#
# Сравнение с базовым бейзлайном:
# Классификация - Sklearn Accuracy: 0.8859, Custom Accuracy: 0.8750
# Регрессия - Sklearn R2: 0.7785, Custom R2: 0.7783

# %% [markdown]
# Получили похожий на обычный бейзлайн результат. Отличие составляет несколько процентов, можно объяснить тем, что в sklearn используется усложенная техника обучения.
# Теперь добавим в модель техники из улучшенного бейзлайна:

# %%
custom_gb_classifier_improved = CustomGradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.05,
    max_depth=3,
    random_state=42
)
custom_gb_classifier_improved.fit(X_heart_train_scaled, y_heart_train)
y_heart_pred_custom_improved = custom_gb_classifier_improved.predict(X_heart_test_scaled)

custom_gb_regressor_improved = CustomGradientBoostingRegressor(
    n_estimators=150,
    learning_rate=0.1,
    max_depth=5,
    random_state=42
)
custom_gb_regressor_improved.fit(X_melbourne_train_scaled, y_melbourne_train)
y_melbourne_pred_custom_improved = custom_gb_regressor_improved.predict(X_melbourne_test_scaled)

accuracy_custom_improved = accuracy_score(y_heart_test, y_heart_pred_custom_improved)
recall_custom_improved = recall_score(y_heart_test, y_heart_pred_custom_improved)

r2_custom_improved = r2_score(y_melbourne_test, y_melbourne_pred_custom_improved)
mae_custom_improved = mean_absolute_error(y_melbourne_test, y_melbourne_pred_custom_improved)

print("\nСамостоятельная имплементация с улучшенными параметрами:")
print(f"Классификация - Accuracy: {accuracy_custom_improved:.4f}, Recall: {recall_custom_improved:.4f}")
print(f"Регрессия - R2: {r2_custom_improved:.4f}, MAE: {mae_custom_improved:,.2f}")

print("\nСравнение с улучшенным бейзлайном:")
print(f"Классификация - Sklearn Improved Accuracy: {accuracy_improved:.4f}, Custom Improved Accuracy: {accuracy_custom_improved:.4f}")
print(f"Регрессия - Sklearn Improved R2: {r2_improved:.4f}, Custom Improved R2: {r2_custom_improved:.4f}")
# Out:
# Самостоятельная имплементация с улучшенными параметрами:
# Классификация - Accuracy: 0.8533, Recall: 0.9216
# Регрессия - R2: 0.8283, MAE: 166,349.43
#
# Сравнение с улучшенным бейзлайном:
# Классификация - Sklearn Improved Accuracy: 0.9130, Custom Improved Accuracy: 0.8533
# Регрессия - Sklearn Improved R2: 0.8302, Custom Improved R2: 0.8283

# %% [markdown]
# Для классификации самостоятельная реализация показала ухудшение результата.
# Это произошло потому что в нашей упрощенной реализации отсутствует параметр subsample, который сильно влиял на обучение.
# Для регрессии результат практически совпадает с sklearn.

# %% [markdown]
# ### Выводы

# %% [markdown]
# - Базовый бейзлайн градиентного бустинга показал хорошие результаты на обеих задачах, превосходя простые алгоритмы.
# - Подбор оптимальных гиперпараметров через кросс-валидацию существенно улучшил качество моделей.
# - Самостоятельная реализация градиентного бустинга показала результаты, близкие к sklearn.
# - Упрощенная реализация не включает все оптимизации sklearn, такие как subsample, что привело к различиям в результатах, особенно заметным для классификации.
